# %% [markdown]
# <a href="https://colab.research.google.com/github/siglimumuni/Published-Articles/blob/main/A_Complete_Guide_to_the_read_csv()_Method_in%C2%A0Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/CRM_Data.csv")

df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,1,2,3,11,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# ...

# %% [markdown]
# ## 1. Promoting rows as headers

# %%
#with the skip rows argument
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/CRM_Data.csv",header=2)

df.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %% [markdown]
# ## 2. Parsing dates in a specified column

# %%
#read the data
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/AirQuality")
#check the datatypes
print(df.dtypes)
# Out:
# Timestamp         object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %%
#read the data with parse_dates argument
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/AirQuality",
                 parse_dates=['Timestamp'])
#check the datatypes
print(df.dtypes)
# Out:
# Timestamp        datetime64[ns]
# CO(GT)                  float64
# PT08.S1(CO)             float64
# NMHC(GT)                float64
# C6H6(GT)                float64
# PT08.S2(NMHC)           float64
# NOx(GT)                 float64
# PT08.S3(NOx)            float64
# NO2(GT)                 float64
# PT08.S4(NO2)            float64
# PT08.S5(O3)             float64
# T                       float64
# RH                      float64
# AH                      float64
# dtype: object

# %% [markdown]
# ## 3. Setting a column as an index

# %%
#read the data and set timestamp column as index
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/AirQuality",
                 parse_dates=['Timestamp'],
                 index_col='Timestamp')

df.head()
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  \
# Timestamp
# 2004-03-10 18:00:00     2.6      1360.00     150.0  11.881723        1045.50
# 2004-03-10 19:00:00     2.0      1292.25     112.0   9.397165         954.75
# 2004-03-10 20:00:00     2.2      1402.00      88.0   8.997817         939.25
# 2004-03-10 21:00:00     2.2      1375.50      80.0   9.228796         948.25
# 2004-03-10 22:00:00     1.6      1272.25      51.0   6.518224         835.50
#
#                      NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# Timestamp
# 2004-03-10 18:00:00    166.0       1056.25    113.0       1692.00
# 2004-03-10 19:00:00    103.0       1173.75     92.0       1558.75
# 2004-03-10 20:00:00    131.0       1140.00    114.0       1554.50
# 2004-03-10 21:00:00    172.0       1092.00    122.0       1583.75
# 2004-03-10 22:00:00    131.0       1205.00    116.0       1490.00
#
#                      PT08.S5(O3)      T         RH        AH
# Timestamp
# ...

# %% [markdown]
# ## 4. Setting the data type of a column

# %%
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/Ecommerce%20Customers")
df.dtypes
# Out:
# Email                    object
# Address                  object
# Avatar                   object
# Avg. Session Length     float64
# Time on App             float64
# Time on Website         float64
# Length of Membership    float64
# Yearly Amount Spent     float64
# dtype: object

# %%
#change column data types
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/Ecommerce%20Customers",
                 dtype={'Email':'string','Address':'string','Avatar':'string'})
df.dtypes
# Out:
# Email                    string
# Address                  string
# Avatar                   string
# Avg. Session Length     float64
# Time on App             float64
# Time on Website         float64
# Length of Membership    float64
# Yearly Amount Spent     float64
# dtype: object

# %% [markdown]
# ## 5. Setting boolean values

# %%
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/churn.csv")
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
#change boolean values
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/churn.csv",
                 true_values = ['yes'],
                 false_values = ['no'])
df.head()
# Out:
#   State  Account Length  Area Code     Phone  Int'l Plan  VMail Plan  \
# 0    KS             128        415  382-4657       False        True
# 1    OH             107        415  371-7191       False        True
# 2    NJ             137        415  358-1921       False       False
# 3    OH              84        408  375-9999        True       False
# 4    OK              75        415  330-6626        True       False
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %% [markdown]
# ## 6. Assigning null values

# %%
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/sample_data.csv")
df.head()
# Out:
#      Name Age Height
# 0    Mike  25      ?
# 1  Sandra  30      ?
# 2   Kerry   ?    1.8
# 3   Jones  24   1.65
# 4  Andrew   ?    1.6

# %%
#return count of null values
df.isnull().sum()
# Out:
# Name      0
# Age       0
# Height    0
# dtype: int64

# %%
#identify null values
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/sample_data.csv",
                 na_values = ['?'])
df.head()
# Out:
#      Name   Age  Height
# 0    Mike  25.0     NaN
# 1  Sandra  30.0     NaN
# 2   Kerry   NaN    1.80
# 3   Jones  24.0    1.65
# 4  Andrew   NaN    1.60

# %%
#return count of null values
df.isnull().sum()
# Out:
# Name      0
# Age       3
# Height    4
# dtype: int64

# %% [markdown]
# ## 7. Reading a fraction of the rows in the data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/yelp.csv")
df.shape
# Out:
# (10000, 10)

# %%
#select first 1000 rows
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/yelp.csv",
                 nrows=1000)
df.shape
# Out:
# (1000, 10)

# %%
#skip first 7000 rows
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/yelp.csv",
                 skiprows=7000)
df.shape
# Out:
# (3000, 10)

# %% [markdown]
# ## 8. Selecting specific columns from the data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/yelp.csv")
df.head()
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id  cool  useful  funny
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0
# ...

# %%
#keep three columns with list of column names
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/yelp.csv",
                 usecols = ['date','stars','text'])
df.head()
# Out:
#          date  stars                                               text
# 0  2011-01-26      5  My wife took me here on my birthday for breakf...
# 1  2011-07-27      5  I have no idea why some people give bad review...
# 2  2012-06-14      4  love the gyro plate. Rice is so good and I als...
# 3  2010-05-27      5  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...
# 4  2012-01-05      5  General Manager Scott Petello is a good egg!!!...

# %%
#keep three columns with list of column index positions
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/yelp.csv",
                 usecols = [1,3,4])
df.head()
# Out:
#          date  stars                                               text
# 0  2011-01-26      5  My wife took me here on my birthday for breakf...
# 1  2011-07-27      5  I have no idea why some people give bad review...
# 2  2012-06-14      4  love the gyro plate. Rice is so good and I als...
# 3  2010-05-27      5  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...
# 4  2012-01-05      5  General Manager Scott Petello is a good egg!!!...

# %% [markdown]
# ## 9. Printing additional information after reading a CSV file

# %%
#keep all columns
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/yelp.csv",
                 verbose = True)
# Out:
# Tokenization took: 115.85 ms
# Type conversion took: 84.43 ms
# Parser memory cleanup took: 0.01 ms

# %%
#keep only three columns
df = pd.read_csv("https://raw.githubusercontent.com/siglimumuni/Datasets/master/yelp.csv",
                 usecols = [1,3,4],
                 verbose = True)
# Out:
# Tokenization took: 55.99 ms
# Type conversion took: 41.34 ms
# Parser memory cleanup took: 0.01 ms
